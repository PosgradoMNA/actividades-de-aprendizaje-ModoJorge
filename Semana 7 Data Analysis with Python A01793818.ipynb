# %% [markdown]
# ## Semana 7: Data Analysis with Python (IBM) A01793818
#
# Jorge Ariel Bermudez Tellería

# %% [markdown]
# ### Desarrollo Modelos

# %%
## En el curso aprenderemos acerca de un modelo de regresión lineal.
## Regresión lineal multiple
# Regresión polinomial

# Recordar que siempre la regresión lineal depende de una ecuación de y= b + mx, donde b es la intersección con el eje y 
# y m es la pendiente

# se debe de entrenar el modelo y comenzar a realizar las predicciones

from sklearn.linear_model import LinearRegression

lm = LinearRegression()

# %%
X = df['X']
Y = df['Y']

lm.fit(X,Y)

Yhat = lm.predict(X)

# Para b

lm.intercept_

# para m

lm.coef_

# %% [markdown]
# ### Evaluación del modelo usando Visualización

# %%
import seaborn as sns
sns.regplot(x ="mpg", y="price", data = df)
plt.ylim(0,)

# %% [markdown]
# ### Regresión polinomial y pipelines

# %% [markdown]
# ### Medidas para la evaluación dentro de la muestra

# %%
## MSE
## R2

from sklearn.metrics import mean_squared_error
mean_squared_error(df['price'],Y_predict_simple_fit)

## El R2 es el coeficiente de correlación el cual es el que muestra la correlacionque existe entre x y y, 
## entre mas cercano a 1 se encuentre mayor será esta.

# %% [markdown]
# ### A continuación enseño el progreso del curso, solo me faltaría elultimo modulo.

# %% [markdown]
# ![image.png](attachment:image.png)
